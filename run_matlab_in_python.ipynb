# %%
# -*-coding:utf-8 -*-
# import all the libraries 
# python==3.8; jupyterlab==3.0.12; lumicks.pylake==0.8.1; matplotlib==3.3.4; more-itertools==8.7.0;
# npTDMS==1.1.0; numpy==1.20.1; opencv-python==4.5.1.48; pandas==1.2.3; scipy==1.6.1; tifffile==2021.3.5
import os
import numpy as np
import cv2
import pylab as pl
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib import collections  as mc
from matplotlib import colors as mcolors
import pandas as pd
from nptdms import TdmsFile
from scipy.signal import savgol_filter
import tifffile as tif
from scipy import interpolate
# %matplotlib widget

# %%
# when running the matlab API code, please ensure all the folder and subfolder are added to path
# you can check it by enter path in the Matlab commond window
import matlab.engine
eng = matlab.engine.start_matlab()

# %%
# you must add nargout=0 to run .m script, otherwise it will run as a function, see https://nl.mathworks.com/matlabcentral/answers/816065-execution-of-script-vgg16-as-a-function-is-not-supported

# eng.main_run(nargout=0)
eng.AutoStepfinder(nargout=0)
# eng.edit('main_run_py',nargout=0)

# %%
# when finish calling matlab, use the below code to end the session; you might need to call again if you use a different matlab script/funciton
# eng.quit()

# %%
history
# Out:
# import matlab.engine
# eng = matlab.engine.start_matlab()
# import matlab.engine
# eng = matlab.engine.start_matlab()
# eng.simple_script(nargout=0)
# eng.quit()
# eng.simple_script(nargout=0)
# eng.quit()
# x = eng.sqrt(float(42))
# print(x)
# eng.sqrt(float(42))
# eng.quit()
# eng.sqrt(float(42))
# eng.sqrt(float(42))
# import matlab.engine
# eng = matlab.engine.start_matlab()
# eng.sqrt(float(42))
# eng.simple_script(nargout=0)
# eng.main_run(nargout=0)
# eng.simple_script(nargout=0)
# eng.simple_script(nargout=0)
# eng.quit()
# a = eng.simple_script(nargout=1)
# print(a)
# eng.quit()
# a = eng.simple_script(nargout=1)
# print(a)
# # eng.quit()
# import matlab.engine
# eng = matlab.engine.start_matlab()
# a = eng.simple_script(nargout=1)
# print(a)
# # eng.quit()
# a = eng.simple_script(nargout=0)
# print(a)
# # eng.quit()
# eng.simple_script(nargout=0)
#
# # eng.quit()
# eng.simple_script(nargout=0)
#
# # eng.quit()
# eng.simple_script(nargout=1)
#
# # eng.quit()
# # eng.simple_script(nargout=1)
# ret = eng.simple_script(1.0,5.0)
# print(ret)
# # eng.quit()
# # eng.simple_script(nargout=1)
# ret = eng.simple_script(1.0,5.0)
# print(ret)
# # eng.quit()
# eng.main_run(nargout=0)
# eng.main_run(nargout=0)
# eng.main_run()
# import matlab.engine
# eng = matlab.engine.start_matlab()
# eng.main_run()
# eng.main_run()
# eng.main_run2()
# eng.quit()
# import matlab.engine
# eng = matlab.engine.start_matlab()
# eng.main_run2()
# # eng.simple_script(nargout=1)
# ret = eng.simple_script(1.0,5.0)
# print(ret)
# # eng.quit()
# # eng.simple_script(nargout=1)
# ret = eng.simple_script(1.0,10.0)
# print(ret)
# # eng.quit()
# eng.main_run()
# # eng.simple_script(nargout=1)
# ret = eng.simple_script(1.0,10.0)
# print(ret)
# # eng.quit()
# eng.main_run()
# eng.main_run()
# eng.main_run()
# eng.simple_script()
# # eng.simple_script(nargout=1)
# ret = eng.simple_script(1.0,10.0)
# print(ret)
# # eng.quit()
# eng.main_run()
# eng.main_run()
# eng.simple_script()
# eng.simple_script(1.0,10.0)
# eng.simple_script(1.0)
# eng.main_run_py()
# eng.main_run_py()
# eng.quit()
# import matlab.engine
# eng = matlab.engine.start_matlab()
# eng.BP_Batch_Segments_for()
# # -*-coding:utf-8 -*-
# # import all the libraries
# # python==3.8; jupyterlab==3.0.12; lumicks.pylake==0.8.1; matplotlib==3.3.4; more-itertools==8.7.0;
# # npTDMS==1.1.0; numpy==1.20.1; opencv-python==4.5.1.48; pandas==1.2.3; scipy==1.6.1; tifffile==2021.3.5
# import os
# import numpy as np
# import cv2
# import pylab as pl
# import matplotlib.pyplot as plt
# import matplotlib.patches as patches
# from matplotlib import collections  as mc
# from matplotlib import colors as mcolors
# import pandas as pd
# from nptdms import TdmsFile
# from scipy.signal import savgol_filter
# import tifffile as tif
# from scipy import interpolate
# %matplotlib widget
# # read and plot the change-point calculated from the Matlab code (from Noemie code)
# cp_name = input('please type in the file name:' ) + '.xlsx'
# cp_path = input('please type in the file path:')
# cp_file = os.path.join(cp_path, cp_name)
# cp = pd.read_excel(cp_file)
# print(cp.head())
# time_index = np.array(cp[0])
# time_index = np.array(cp['time serials'])
# time_index = np.array(cp['time serials'])
# print(time_index)
# eng.BP_Batch_Segments_for(time_index,intensity,'sigma',1,'linear',0,nargout=2)
# time_index = np.array(cp['time serials'])
# intensity = np.array(cp['filtered intensity'])
# eng.BP_Batch_Segments_for(time_index,intensity,'sigma',1,'linear',0,nargout=2)
# print(type(time_index))
# time_index = cp['time serials']
# intensity = cp['filtered intensity']
# print(type(time_index))
# eng.BP_Batch_Segments_for(time_index,intensity,'sigma',1,'linear',0,nargout=2)
# time_index = np.array(cp['time serials']).astype(int)
# intensity = np.array(cp['filtered intensity'])astype(int)
# time_index = np.array(cp['time serials']).astype(int)
# intensity = np.array(cp['filtered intensity']).astype(int)
# print(type(time_index))
# eng.BP_Batch_Segments_for(time_index,intensity,'sigma',1,'linear',0,nargout=2)
# time_index = np.array(cp['time serials'])
# intensity = np.array(cp['filtered intensity'])
# print(type(time_index))
# print(type(np.double(time_index)))
# print(type(np.double(time_index)))
# print(time_index)
# print(np.double(time_index))
# eng.sqrt(float(42))
# eng.main_run_py()
# a = eng.main_run_py()
# eng.main_run_py(nargout=0)
# eng.main_run_py(nargout=0)
# eng.main_run_py(nargout=0)
# eng.main_run_py(nargout=1)
# # you need to add nargout=0 to run .m script, otherwise it will run as a function, see https://nl.mathworks.com/matlabcentral/answers/816065-execution-of-script-vgg16-as-a-function-is-not-supported
# eng.main_run2(nargout=0)
# # you need to add nargout=0 to run .m script, otherwise it will run as a function, see https://nl.mathworks.com/matlabcentral/answers/816065-execution-of-script-vgg16-as-a-function-is-not-supported
# eng.main_run2(nargout=0)
# # you need to add nargout=0 to run .m script, otherwise it will run as a function, see https://nl.mathworks.com/matlabcentral/answers/816065-execution-of-script-vgg16-as-a-function-is-not-supported
# eng.main_run_py(nargout=0)
# # you need to add nargout=0 to run .m script, otherwise it will run as a function, see https://nl.mathworks.com/matlabcentral/answers/816065-execution-of-script-vgg16-as-a-function-is-not-supported
# eng.detect_change_point_function('C:\Users\Stefan\Desktop\test\','overlap_intensity.xlsx','C:\Users\Stefan\Desktop\test_Results\',6,1)nargout=0)
# PathName = r'C:\Users\Stefan\Desktop\test\'
# FolderSave = r'C:\Users\Stefan\Desktop\test_Results\'
# FileName = 'overlap_intensity.xlsx'
# PathName = r'C:\Users\Stefan\Desktop\test\'
#
# FolderSave = r'C:\Users\Stefan\Desktop\test_Results\'
# FileName = 'overlap_intensity.xlsx'
# PathName = r'C:\Users\Stefan\Desktop\test"\"'
#
# # FolderSave = r'C:\Users\Stefan\Desktop\test_Results\'
# # FileName = 'overlap_intensity.xlsx'
# print(PathName)
# PathName = r'C:\Users\Stefan\Desktop\test\'
#
# # FolderSave = r'C:\Users\Stefan\Desktop\test_Results\'
# # FileName = 'overlap_intensity.xlsx'
# print(PathName)
# PathName = r'C:\Users\Stefan\Desktop\test'
#
# # FolderSave = r'C:\Users\Stefan\Desktop\test_Results\'
# # FileName = 'overlap_intensity.xlsx'
# print(PathName)
# PathName = r'C:\Users\Stefan\Desktop\test' + "\"
#
# # FolderSave = r'C:\Users\Stefan\Desktop\test_Results\'
# # FileName = 'overlap_intensity.xlsx'
# print(PathName)
# PathName = r'C:\Users\Stefan\Desktop\test' + "\""
#
# # FolderSave = r'C:\Users\Stefan\Desktop\test_Results\'
# # FileName = 'overlap_intensity.xlsx'
# print(PathName)
# PathName = r'C:\Users\Stefan\Desktop\test' + "\\"
#
# # FolderSave = r'C:\Users\Stefan\Desktop\test_Results\'
# # FileName = 'overlap_intensity.xlsx'
# print(PathName)
# PathName = r'C:\Users\Stefan\Desktop\test' + "\\"
# FolderSave = r'C:\Users\Stefan\Desktop\test_Results' + "\\"
# FileName = 'overlap_intensity.xlsx'
# print(PathName)
# PathName = r'C:\Users\Stefan\Desktop\test' + "\\"
# FolderSave = r'C:\Users\Stefan\Desktop\test_Results' + "\\"
# FileName = 'overlap_intensity.xlsx'
# print(FolderSave)
# PathName = r'C:\Users\Stefan\Desktop\test' + "\\"
# FolderSave = r'C:\Users\Stefan\Desktop\test_Results' + "\\"
# FileName = 'overlap_intensity.xlsx'
# print(FileName)
# # you need to add nargout=0 to run .m script, otherwise it will run as a function, see https://nl.mathworks.com/matlabcentral/answers/816065-execution-of-script-vgg16-as-a-function-is-not-supported
# eng.detect_change_point_function(PathName,FileName,FolderSave,6,1,nargout=0)
# PathName = r'C:\Users\Stefan\Desktop\test' + "\\"
# FolderSave = r'C:\Users\Stefan\Desktop\test_Results' + "\\"
# FileName = 'overlap_intensity.xlsx'
# PathName = r'C:\Users\Stefan\Desktop\test' + "\\"
# FolderSave = r'C:\Users\Stefan\Desktop\test_Results' + "\\"
# FileName = '20190926-015-2.xlsx'
# # you need to add nargout=0 to run .m script, otherwise it will run as a function, see https://nl.mathworks.com/matlabcentral/answers/816065-execution-of-script-vgg16-as-a-function-is-not-supported
# eng.detect_change_point_function(PathName,FileName,FolderSave,6,1,nargout=0)
# # you must add nargout=0 to run .m script, otherwise it will run as a function, see https://nl.mathworks.com/matlabcentral/answers/816065-execution-of-script-vgg16-as-a-function-is-not-supported
# # eng.detect_change_point_function(PathName,FileName,FolderSave,6,1,nargout=0)
# eng.main_run_py(nargout=0))
# # you must add nargout=0 to run .m script, otherwise it will run as a function, see https://nl.mathworks.com/matlabcentral/answers/816065-execution-of-script-vgg16-as-a-function-is-not-supported
# # eng.detect_change_point_function(PathName,FileName,FolderSave,6,1,nargout=0)
# eng.main_run_py(nargout=0)
# PathName = r'C:\Users\Stefan\Desktop\test' + "\\"
# FolderSave = r'C:\Users\Stefan\Desktop\test_Results' + "\\"
# FileName = '20190926-015-2.xlsx'
# # you must add nargout=0 to run .m script, otherwise it will run as a function, see https://nl.mathworks.com/matlabcentral/answers/816065-execution-of-script-vgg16-as-a-function-is-not-supported
# # eng.detect_change_point_function(PathName,FileName,FolderSave,6,1,nargout=0)
# # eng.main_run_py(nargout=0)
# eng.test_func(PathName,FileName,nargout=0)
# # you must add nargout=0 to run .m script, otherwise it will run as a function, see https://nl.mathworks.com/matlabcentral/answers/816065-execution-of-script-vgg16-as-a-function-is-not-supported
# # eng.detect_change_point_function(PathName,FileName,FolderSave,6,1,nargout=0)
# # eng.main_run_py(nargout=0)
# eng.test_func(PathName,FileName,nargout=0)
# # you must add nargout=0 to run .m script, otherwise it will run as a function, see https://nl.mathworks.com/matlabcentral/answers/816065-execution-of-script-vgg16-as-a-function-is-not-supported
# # eng.detect_change_point_function(PathName,FileName,FolderSave,6,1,nargout=0)
# # eng.main_run_py(nargout=0)
# eng.test_func(PathName,FileName,nargout=0)
# # you must add nargout=0 to run .m script, otherwise it will run as a function, see https://nl.mathworks.com/matlabcentral/answers/816065-execution-of-script-vgg16-as-a-function-is-not-supported
# eng.detect_change_point_function(PathName,FileName,FolderSave,6,1,nargout=0)
# # eng.main_run_py(nargout=0)
# # eng.test_func(PathName,FileName,nargout=0)
# # you must add nargout=0 to run .m script, otherwise it will run as a function, see https://nl.mathworks.com/matlabcentral/answers/816065-execution-of-script-vgg16-as-a-function-is-not-supported
# eng.detect_change_point_function(PathName,FileName,FolderSave,5,0.05,nargout=0)
# # eng.main_run_py(nargout=0)
# # eng.test_func(PathName,FileName,nargout=0)
# # you must add nargout=0 to run .m script, otherwise it will run as a function, see https://nl.mathworks.com/matlabcentral/answers/816065-execution-of-script-vgg16-as-a-function-is-not-supported
# # eng.detect_change_point_function(PathName,FileName,FolderSave,5,0.05,nargout=0)
# eng.detect_change_point_function(r'C:\Users\Stefan\Desktop\test'+ "\\",'20190926-015-2.xlsx','C:\Users\Stefan\Desktop\test_Results'+ "\\",6,0.05,nargout=0)
# # eng.main_run_py(nargout=0)
# # eng.test_func(PathName,FileName,nargout=0)
# # you must add nargout=0 to run .m script, otherwise it will run as a function, see https://nl.mathworks.com/matlabcentral/answers/816065-execution-of-script-vgg16-as-a-function-is-not-supported
# # eng.detect_change_point_function(PathName,FileName,FolderSave,5,0.05,nargout=0)
# eng.detect_change_point_function(r'C:\Users\Stefan\Desktop\test'+ "\\",'20190926-015-2.xlsx',r'C:\Users\Stefan\Desktop\test_Results'+ "\\",6,0.05,nargout=0)
# # eng.main_run_py(nargout=0)
# # eng.test_func(PathName,FileName,nargout=0)
# # you must add nargout=0 to run .m script, otherwise it will run as a function, see https://nl.mathworks.com/matlabcentral/answers/816065-execution-of-script-vgg16-as-a-function-is-not-supported
# # eng.detect_change_point_function(PathName,FileName,FolderSave,5,0.05,nargout=0)
# eng.detect_change_point_function(r'C:\Users\Stefan\Desktop\test'+ "\\",'20190926-015-2.xlsx',r'C:\Users\Stefan\Desktop\test_Results'+ "\\",6,0.05,nargout=0)
# # eng.main_run_py(nargout=0)
# # eng.test_func(PathName,FileName,nargout=0)
# # you must add nargout=0 to run .m script, otherwise it will run as a function, see https://nl.mathworks.com/matlabcentral/answers/816065-execution-of-script-vgg16-as-a-function-is-not-supported
# # eng.detect_change_point_function(PathName,FileName,FolderSave,5,0.05,nargout=0)
# eng.detect_change_point_function(r'C:\Users\Stefan\Desktop\test'+ "\\",'20190926-015-2.xlsx',r'C:\Users\Stefan\Desktop\test_Results'+ "\\",6,0.05,nargout=0)
# # eng.main_run_py(nargout=0)
# # eng.test_func(PathName,FileName,nargout=0)
# eng.main_run_py(nargout=0)
# # eng.main_run_py(nargout=0)
# eng.edit('main_run_py',nargout=0)
# eng.main_run_py(nargout=0)
# # eng.edit('main_run_py',nargout=0)
# eng.main_run_py(nargout=0)
# # eng.edit('main_run_py',nargout=0)
# # eng.main_run_py(nargout=0)
# eng.edit('main_run_py',nargout=0)
# eng.main_run_py(nargout=0)
# # eng.edit('main_run_py',nargout=0)
# # eng.main_run_py(nargout=0)
# eng.edit('main_run_py',nargout=0)
# eng.main_run_py(nargout=0)
# # eng.edit('main_run_py',nargout=0)
# # eng.main_run_py(nargout=0)
# eng.edit('main_run_py',nargout=0)
# eng.main_run_py(nargout=0)
# # eng.edit('main_run_py',nargout=0)
# eng.main_run(nargout=0)
# # eng.edit('main_run_py',nargout=0)
# eng.main_run(nargout=0)
# # eng.edit('main_run_py',nargout=0)
# eng.main_run(nargout=0)
# # eng.edit('main_run_py',nargout=0)
# import matlab.engine
# eng = matlab.engine.start_matlab()
# eng.main_run(nargout=0)
# # eng.edit('main_run_py',nargout=0)
# import matlab.engine
# eng = matlab.engine.start_matlab()
# eng.main_run(nargout=0)
# # eng.edit('main_run_py',nargout=0)
# # eng.main_run(nargout=0)
# eng.AutoStepFinder(nargout=0)
# # eng.edit('main_run_py',nargout=0)
# # eng.main_run(nargout=0)
# eng.AutoStepfinder(nargout=0)
# # eng.edit('main_run_py',nargout=0)
# history
